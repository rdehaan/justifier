# %%
from justifier import find_justification

# %%
profile = [
    ['a','c','b'],
    ['a','b','c'],
]
outcomes = ['a']
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
find_justification(
    profile,
    outcomes,
    axioms,
    num_voters=3,
    num_profiles=3,
    num_axiom_instances=1,
    verbose=True,
    num_solutions=1,
)
# Out:
# .. Grounding ..
# .. Solving ..
# == Justification 1 ==
#
# Profile 1: [['a', 'b', 'c'], ['a', 'c', 'b']]
# Axiom instance: ('unanimity', 1)
#
# .. Search completed ..
# .. Total time: 0.08 seconds ..
# .. Total number of refinements: 0 ..

# %%
profile = [
    ['a','b','c'],
    ['a','c','b'],
    ['b','a','c'],
    ['a','b','c'],
    ['a','c','b'],
    ['b','a','c'],
]
outcomes = ['a']
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
find_justification(
    profile,
    outcomes,
    axioms,
    num_voters=6,
    num_profiles=4,
    num_axiom_instances=None,
    verbose=True,
    num_solutions=1,
    base_timeout=30,
    subseq_timeout=15,
    profile_size_bounds=[1,2,3],
)
# Out:
# .. Grounding ..
# .. Solving ..
# == Justification 1 ==
#
# Profile 1: [['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['b', 'a', 'c'], ['b', 'a', 'c']]
# Profile 2: [['a', 'c', 'b']]
# Profile 3: [['a', 'b', 'c'], ['b', 'a', 'c']]
# Profile 4: [['a', 'b', 'c'], ['a', 'c', 'b'], ['b', 'a', 'c']]
# Axiom instance: ('reinforcement', 2, 3, 4)
# Axiom instance: ('neutrality', 'a', 'b', 3, 3)
# Axiom instance: ('pareto', 'b', 2)
# Axiom instance: ('pareto', 'c', 3)
# Axiom instance: ('pareto', 'c', 2)
# Axiom instance: ('faithfulness', 2)
# Axiom instance: ('reinforcement', 4, 4, 1)
# Axiom instance: ('unanimity', 2)
# Axiom instance: ('pareto', 'c', 4)
# Axiom instance: ('pareto', 'c', 1)
#
# .. Search completed ..
# .. Total time: 0.33 seconds ..
# .. Total number of refinements: 0 ..

# %%
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
# ]
# outcomes = ['a']
# axioms = [
#     "faithfulness",
#     "unanimity",
#     "cancellation",
#     "pareto",
#     "neutrality",
#     "reinforcement",
#     # "positive_responsiveness",
#     # "condorcet",
# ]
# find_justification(
#     profile,
#     outcomes,
#     axioms,
#     num_voters=9,
#     num_profiles=4,
#     num_axiom_instances=None,
#     verbose=True,
#     num_solutions=1,
#     base_timeout=30,
#     subseq_timeout=30,
# )

# %%
profile = [
    ['a','b','c'],
    ['a','b','c'],
    ['c','b','a'],
    ['a','b','c'],
    ['a','b','c'],
    ['c','b','a'],
]
outcomes = ['a']
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
find_justification(
    profile,
    outcomes,
    axioms,
    num_voters=6,
    num_profiles=3,
    num_axiom_instances=None,
    verbose=True,
    num_solutions=1,
    base_timeout=30,
    subseq_timeout=15,
)
# Out:
# .. Grounding ..
# .. Solving ..
# == Justification 1 ==
#
# Profile 1: [['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'b', 'c'], ['c', 'b', 'a'], ['c', 'b', 'a']]
# Profile 2: [['a', 'b', 'c'], ['a', 'b', 'c']]
# Profile 3: [['a', 'b', 'c'], ['a', 'b', 'c'], ['c', 'b', 'a'], ['c', 'b', 'a']]
# Axiom instance: ('pareto', 'b', 2)
# Axiom instance: ('unanimity', 2)
# Axiom instance: ('neutrality', 'a', 'c', 3, 3)
# Axiom instance: ('pareto', 'c', 2)
# Axiom instance: ('cancellation', 3)
# Axiom instance: ('reinforcement', 2, 3, 1)
#
# .. Search completed ..
# .. Total time: 0.34 seconds ..
# .. Total number of refinements: 0 ..

# %%
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','c','a'],
#     ['c','a','b'],
# ]
# outcomes = ['a']
# axioms = [
#     "faithfulness",
#     "unanimity",
#     "cancellation",
#     "pareto",
#     "neutrality",
#     "reinforcement",
#     "positive_responsiveness",
#     # "condorcet",
# ]
# find_justification(
#     profile,
#     outcomes,
#     axioms,
#     num_voters=4,
#     num_profiles=4,
#     num_axiom_instances=4,
#     verbose=True,
#     num_solutions=1,
#     base_timeout=15,
#     subseq_timeout=15,
# )

# %%
# # HARD
# profile = [
#     ['a','b','c'],
#     ['c','a','b'],
#     ['c','a','b'],
# ]
# outcomes = ['a', 'c']
# axioms = [
#     # "faithfulness",
#     # "unanimity",
#     "cancellation",
#     "pareto",
#     "neutrality",
#     "reinforcement",
#     # "positive_responsiveness",
#     # "condorcet",
# ]
# find_justification(
#     profile,
#     outcomes,
#     axioms,
#     num_voters=5,
#     num_profiles=6,
#     num_axiom_instances=None,
#     verbose=True,
#     num_solutions=1,
#     base_timeout=300,
#     subseq_timeout=60,
# )

# %%
profile = [
    ['a','b','c'],
    ['a','c','b'],
    ['b','c','a'],
    ['b','a','c'],
]
outcomes = ['a', 'b']
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
find_justification(
    profile,
    outcomes,
    axioms,
    num_voters=4,
    num_profiles=3,
    num_axiom_instances=None,
    verbose=True,
    num_solutions=1,
    base_timeout=15,
    subseq_timeout=15,
)
# Out:
# .. Grounding ..
# .. Solving ..
# == Justification 1 ==
#
# Profile 1: [['a', 'b', 'c'], ['a', 'c', 'b'], ['b', 'a', 'c'], ['b', 'c', 'a']]
# Profile 2: [['a', 'c', 'b'], ['b', 'c', 'a']]
# Profile 3: [['a', 'b', 'c'], ['b', 'a', 'c']]
# Axiom instance: ('neutrality', 'a', 'b', 3, 3)
# Axiom instance: ('cancellation', 2)
# Axiom instance: ('pareto', 'c', 3)
# Axiom instance: ('neutrality', 'a', 'b', 2, 2)
# Axiom instance: ('neutrality', 'a', 'b', 1, 1)
# Axiom instance: ('reinforcement', 2, 3, 1)
#
# .. Search completed ..
# .. Total time: 0.15 seconds ..
# .. Total number of refinements: 2 ..

# %%
# HARD
profile = [
    ['a','b','c'],
    ['c','a','b'],
    ['c','a','b'],
]
outcomes = ['a', 'c']
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
find_justification(
    profile,
    outcomes,
    axioms,
    num_voters=5,
    num_profiles=6,
    num_axiom_instances=None,
    verbose=True,
    num_solutions=1,
    base_timeout=30,
    subseq_timeout=60,
    profile_size_bounds=[2,2,3,3,5],
)
# Out:
# .. Grounding ..
# .. Solving ..
# == Justification 1 ==
#
# Profile 1: [['a', 'b', 'c'], ['c', 'a', 'b'], ['c', 'a', 'b']]
# Profile 2: [['a', 'c', 'b'], ['b', 'c', 'a']]
# Profile 3: [['a', 'c', 'b'], ['c', 'a', 'b']]
# Profile 4: [['a', 'b', 'c'], ['b', 'c', 'a'], ['c', 'a', 'b']]
# Profile 5: [['a', 'c', 'b'], ['b', 'a', 'c'], ['c', 'b', 'a']]
# Profile 6: [['a', 'b', 'c'], ['a', 'c', 'b'], ['b', 'c', 'a'], ['c', 'a', 'b'], ['c', 'a', 'b']]
# Axiom instance: ('cancellation', 2)
# Axiom instance: ('neutrality', 'a', 'b', 4, 5)
# Axiom instance: ('pareto', 'b', 1)
# Axiom instance: ('neutrality', 'a', 'b', 2, 2)
# Axiom instance: ('neutrality', 'b', 'c', 4, 5)
# Axiom instance: ('neutrality', 'a', 'c', 3, 3)
# Axiom instance: ('reinforcement', 3, 4, 6)
# Axiom instance: ('reinforcement', 1, 2, 6)
# Axiom instance: ('pareto', 'b', 3)
# Axiom instance: ('neutrality', 'a', 'c', 4, 5)
#
# .. Search completed ..
# .. Total time: 1.79 seconds ..
# .. Total number of refinements: 178 ..
