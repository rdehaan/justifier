# %%
from justifier import find_justification, find_justification_auto

# %%
# ############
# profile = [
#     ['a','b','c'],
#     ['a','b','c'],
#     ['c','b','a'],
#     ['a','b','c'],
#     ['a','b','c'],
#     ['c','b','a'],
# ]
# outcomes = ['a']

# ############
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
# ]
# outcomes = ['a']

# ############
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','c','a'],
#     ['c','a','b'],
# ]
# outcomes = ['a']

# ############
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','c','a'],
#     ['b','a','c'],
# ]
# outcomes = ['a', 'b']

############
profile = [
    ['a','b','c'],
    ['a','c','b'],
    ['b','a','c'],
    ['a','b','c'],
    ['a','c','b'],
    ['b','a','c'],
    ['a','b','c'],
    ['a','c','b'],
    ['b','a','c'],
]
outcomes = ['a']

# ############
# profile = [
#     ['a','b','c'],
#     ['c','a','b'],
#     ['c','a','b'],
# ]
# outcomes = ['a', 'c']

# %%
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
profiles, instances = find_justification_auto(
    profile,
    outcomes,
    axioms,
    verbose=True,
    timeout=30,
)
print(profiles)
# Out:
# ~~ Trying with [2, 3, 4, 5] & None ~~
# .. Grounding ..
# .. Solving ..
# == Justification 1 ==
#
# Profile 1: [['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['b', 'a', 'c'], ['b', 'a', 'c'], ['b', 'a', 'c']]
# Profile 2: [['a', 'b', 'c'], ['b', 'a', 'c']]
# Profile 3: [['a', 'c', 'b'], ['a', 'c', 'b'], ['a', 'c', 'b']]
# Profile 4: [['a', 'b', 'c'], ['a', 'b', 'c'], ['b', 'a', 'c'], ['b', 'a', 'c']]
# Profile 5: [['a', 'b', 'c'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['b', 'a', 'c']]
# Axiom instance: ('reinforcement', 2, 3, 5)
# Axiom instance: ('pareto', 'c', 5)
# Axiom instance: ('pareto', 'c', 2)
# Axiom instance: ('pareto', 'b', 3)
# Axiom instance: ('reinforcement', 4, 5, 1)
# Axiom instance: ('neutrality', 'a', 'b', 2, 2)
# Axiom instance: ('pareto', 'c', 1)
# Axiom instance: ('pareto', 'c', 4)
# Axiom instance: ('unanimity', 3)
# Axiom instance: ('pareto', 'c', 3)
# Axiom instance: ('neutrality', 'a', 'b', 4, 4)
# Axiom instance: ('reinforcement', 2, 2, 4)
#
# .. Search completed ..
# .. Total time: 1.35 seconds ..
# .. Total number of refinements: 44 ..
# ~~ Result found ~~
# [[['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['b', 'a', 'c'], ['b', 'a', 'c'], ['b', 'a', 'c']], [['a', 'b', 'c'], ['b', 'a', 'c']], [['a', 'c', 'b'], ['a', 'c', 'b'], ['a', 'c', 'b']], [['a', 'b', 'c'], ['a', 'b', 'c'], ['b', 'a', 'c'], ['b', 'a', 'c']], [['a', 'b', 'c'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['b', 'a', 'c']]]
