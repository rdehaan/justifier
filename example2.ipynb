# %%
from justifier import find_justification_auto, pretty_justification

# %%
# ############
# profile = [
#     ['a','b','c'],
#     ['a','b','c'],
#     ['c','b','a'],
#     ['a','b','c'],
#     ['a','b','c'],
#     ['c','b','a'],
# ]
# outcomes = ['a']

# ############
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
# ]
# outcomes = ['a']

# ############
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','c','a'],
#     ['c','a','b'],
# ]
# outcomes = ['a']

# ############
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','c','a'],
#     ['b','a','c'],
# ]
# outcomes = ['a', 'b']

# ############
# profile = [
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
#     ['a','b','c'],
#     ['a','c','b'],
#     ['b','a','c'],
# ]
# outcomes = ['a']

############
profile = [
    ['a','b','c'],
    ['c','a','b'],
    ['c','a','b'],
]
outcomes = ['a', 'c']

# %%
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
profiles, instances = find_justification_auto(
    profile,
    outcomes,
    axioms,
    verbose=True,
    timeout=15,
)

print("### Final solution: ###")
print(pretty_justification(profiles, instances))
# Out:
# ~~ Trying with [1, 2, 3] & None ~~
# .. Grounding ..
# .. Solving ..
# .. Search completed ..
# .. Total time: 0.11 seconds ..
# .. Total number of refinements: 0 ..
# ~~ Trying with [2, 3, 3] & [1, 2, 3] ~~
# .. Grounding ..
# .. Solving ..
# .. Search completed ..
# .. Total time: 0.11 seconds ..
# .. Total number of refinements: 0 ..
# ~~ Trying with [3, 3, 3] & [2, 3, 3] ~~
# .. Grounding ..
# .. Solving ..
# .. Search completed ..
# .. Total time: 0.11 seconds ..
# .. Total number of refinements: 0 ..
# ~~ Trying with [1, 2, 3, 4] & [0, 0, 0, 4] ~~
# .. Grounding ..
# .. Solving ..
# .. Search completed ..
# .. Total time: 0.34 seconds ..
# .. Total number of refinements: 20 ..
# ~~ Trying with [2, 3, 4, 4] & [1, 2, 3, 4] ~~
# .. Grounding ..
# .. Solving ..
# .. Search completed ..
# .. Total time: 0.79 seconds ..
# .. Total number of refinements: 44 ..
# ~~ Trying with [3, 4, 4, 4] & [2, 3, 4, 4] ~~
# .. Grounding ..
# .. Solving ..
# .. Search completed ..
# ...
