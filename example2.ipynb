# %%
from justifier import find_justification

# %%
profile = [
    ['a','b','c'],
    ['a','c','b'],
    ['b','a','c'],
    ['a','b','c'],
    ['a','c','b'],
    ['b','a','c'],
]
outcomes = ['a']
axioms = [
    "faithfulness",
    "unanimity",
    "cancellation",
    "pareto",
    "neutrality",
    "reinforcement",
    # "positive_responsiveness",
    # "condorcet",
]
for profiles, instances in find_justification(
    profile,
    outcomes,
    axioms,
    num_voters=6,
    num_profiles=4,
    num_axiom_instances=None,
    verbose=True,
    num_solutions=2,
    base_timeout=30,
    subseq_timeout=15,
    profile_size_bounds=[2,3,4],
    fixed_profiles=[[['a', 'c', 'b'], ['a', 'c', 'b']], [['c', 'a', 'b'], ['c', 'a', 'b']], [['a', 'b', 'c'], ['a', 'b', 'c'], ['b', 'a', 'c'], ['b', 'a', 'c']]],
):
    print(profiles)
# Out:
# .. Grounding ..
# .. Solving ..
# == Justification 1 ==
#
# Profile 1: [['a', 'b', 'c'], ['a', 'b', 'c'], ['a', 'c', 'b'], ['a', 'c', 'b'], ['b', 'a', 'c'], ['b', 'a', 'c']]
# Profile 2: [['a', 'c', 'b'], ['a', 'c', 'b']]
# Profile 3: [['c', 'a', 'b'], ['c', 'a', 'b']]
# Profile 4: [['a', 'b', 'c'], ['a', 'b', 'c'], ['b', 'a', 'c'], ['b', 'a', 'c']]
# Axiom instance: ('unanimity', 2)
# Axiom instance: ('pareto', 'b', 2)
# Axiom instance: ('reinforcement', 2, 4, 1)
# Axiom instance: ('neutrality', 'a', 'b', 4, 4)
# Axiom instance: ('neutrality', 'a', 'c', 2, 3)
# Axiom instance: ('pareto', 'c', 2)
# Axiom instance: ('unanimity', 3)
# Axiom instance: ('pareto', 'b', 3)
# Axiom instance: ('pareto', 'a', 3)
# Axiom instance: ('pareto', 'c', 4)
# Axiom instance: ('pareto', 'c', 1)
#
# ...
